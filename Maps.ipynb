# %%
from ipyleaflet import Map, basemaps, Marker
import geocoder

me = geocoder.ip("me")

m=Map(
    basemap=basemaps.OpenTopoMap,
    center=(me.latlng),
    zoom=10,
)

m.add_layer(Marker(location=(me.latlng)))

m
# Out:
# Map(center=[52.2333, 8.1667], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…

# %%
from ipyleaflet import Map, basemaps, Marker
from geopy.
